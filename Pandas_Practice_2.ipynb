# %%
import pandas as pd
#reading specific columns from CSV
df = pd.read_csv('Iris.csv', usecols= ['Id','SepalLengthCm','PetalLengthCm'])
df
# Out:
#       Id  SepalLengthCm  PetalLengthCm
# 0      1            5.1            1.4
# 1      2            4.9            1.4
# 2      3            4.7            1.3
# 3      4            4.6            1.5
# 4      5            5.0            1.4
# ..   ...            ...            ...
# 145  146            6.7            5.2
# 146  147            6.3            5.0
# 147  148            6.5            5.2
# 148  149            6.2            5.4
# 149  150            5.9            5.1
#
# [150 rows x 3 columns]

# %%
df.iloc[1,2]
# Out:
# 1.4

# %%
df.iloc[2,1]
# Out:
# 4.7

# %%
#Problem- Retrive the details of all the species whose SepalLengthCm is grater than 3
df = pd.read_csv('Iris.csv')
df.loc[df['SepalLengthCm'] > 3 ].head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.loc[df['SepalLengthCm'] > 3 ]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
#for less than 4
df.loc[df['SepalLengthCm'] < 4 ]  #output should be blank
# Out:
# Empty DataFrame
# Columns: [Id, SepalLengthCm, SepalWidthCm, PetalLengthCm, PetalWidthCm, Species]
# Index: []

# %%
#Problem- Retrive the details of all the species whose SepalLengthCm is grater than 5 and Species is Iris-virginica
df.loc[(df['Species'] == 'Iris-virginica') & (df['SepalLengthCm'] > 5)]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 100  101            6.3           3.3            6.0           2.5
# 101  102            5.8           2.7            5.1           1.9
# 102  103            7.1           3.0            5.9           2.1
# 103  104            6.3           2.9            5.6           1.8
# 104  105            6.5           3.0            5.8           2.2
# 105  106            7.6           3.0            6.6           2.1
# 107  108            7.3           2.9            6.3           1.8
# 108  109            6.7           2.5            5.8           1.8
# 109  110            7.2           3.6            6.1           2.5
# 110  111            6.5           3.2            5.1           2.0
# 111  112            6.4           2.7            5.3           1.9
# 112  113            6.8           3.0            5.5           2.1
# 113  114            5.7           2.5            5.0           2.0
# ...

# %%
#Problem- sort the details on the basis SepalWidthCm
df.sort_values(by = 'SepalWidthCm')
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 60    61            5.0           2.0            3.5           1.0
# 62    63            6.0           2.2            4.0           1.0
# 119  120            6.0           2.2            5.0           1.5
# 68    69            6.2           2.2            4.5           1.5
# 41    42            4.5           2.3            1.3           0.3
# ..   ...            ...           ...            ...           ...
# 16    17            5.4           3.9            1.3           0.4
# 14    15            5.8           4.0            1.2           0.2
# 32    33            5.2           4.1            1.5           0.1
# 33    34            5.5           4.2            1.4           0.2
# 15    16            5.7           4.4            1.5           0.4
#
#              Species
# 60   Iris-versicolor
# 62   Iris-versicolor
# 119   Iris-virginica
# 68   Iris-versicolor
# 41       Iris-setosa
# ..               ...
# ...

# %%
#descending order
df.sort_values(by = 'SepalWidthCm', ascending=False)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 15    16            5.7           4.4            1.5           0.4
# 33    34            5.5           4.2            1.4           0.2
# 32    33            5.2           4.1            1.5           0.1
# 14    15            5.8           4.0            1.2           0.2
# 16    17            5.4           3.9            1.3           0.4
# ..   ...            ...           ...            ...           ...
# 87    88            6.3           2.3            4.4           1.3
# 62    63            6.0           2.2            4.0           1.0
# 68    69            6.2           2.2            4.5           1.5
# 119  120            6.0           2.2            5.0           1.5
# 60    61            5.0           2.0            3.5           1.0
#
#              Species
# 15       Iris-setosa
# 33       Iris-setosa
# 32       Iris-setosa
# 14       Iris-setosa
# 16       Iris-setosa
# ..               ...
# ...

# %%
#sort a row ascending and other descending 
df.sort_values(['SepalWidthCm','PetalLengthCm'] , ascending=(1,0))
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 60    61            5.0           2.0            3.5           1.0
# 119  120            6.0           2.2            5.0           1.5
# 68    69            6.2           2.2            4.5           1.5
# 62    63            6.0           2.2            4.0           1.0
# 87    88            6.3           2.3            4.4           1.3
# ..   ...            ...           ...            ...           ...
# 16    17            5.4           3.9            1.3           0.4
# 14    15            5.8           4.0            1.2           0.2
# 32    33            5.2           4.1            1.5           0.1
# 33    34            5.5           4.2            1.4           0.2
# 15    16            5.7           4.4            1.5           0.4
#
#              Species
# 60   Iris-versicolor
# 119   Iris-virginica
# 68   Iris-versicolor
# 62   Iris-versicolor
# 87   Iris-versicolor
# ..               ...
# ...

# %%
# How many species belongs to each type?- Using groupby
df.groupby(['Species']).count()[['Id']]
# Out:
#                  Id
# Species
# Iris-setosa      50
# Iris-versicolor  50
# Iris-virginica   50

# %%
df1 = pd.DataFrame({'employee': ['Jyoti', 'Sapna', 'Raj', 'Ramaswamy'],
                    'group': ['Accounting', 'Engineering', 'Engineering', 'HR']})
df2 = pd.DataFrame({'employee': ['Jyoti', 'Sapna', 'Raj', 'Ramaswamy'],
                    'hire_date': [2004, 2008, 2012, 2014]})
display(df1,df2)
# Out:
#     employee        group
# 0      Jyoti   Accounting
# 1      Sapna  Engineering
# 2        Raj  Engineering
# 3  Ramaswamy           HR
#     employee  hire_date
# 0      Jyoti       2004
# 1      Sapna       2008
# 2        Raj       2012
# 3  Ramaswamy       2014

# %%
pd.concat([df1,df2], sort = False)
# Out:
#     employee        group  hire_date
# 0      Jyoti   Accounting        NaN
# 1      Sapna  Engineering        NaN
# 2        Raj  Engineering        NaN
# 3  Ramaswamy           HR        NaN
# 0      Jyoti          NaN     2004.0
# 1      Sapna          NaN     2008.0
# 2        Raj          NaN     2012.0
# 3  Ramaswamy          NaN     2014.0

# %%
df3 = pd.merge(df1,df2)
df3
# Out:
#     employee        group  hire_date
# 0      Jyoti   Accounting       2004
# 1      Sapna  Engineering       2008
# 2        Raj  Engineering       2012
# 3  Ramaswamy           HR       2014
